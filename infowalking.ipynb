# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sec  = pd.read_csv('dataset_5secondWindow.csv')
df_sec.head(20)
# Out:
#     Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0            0  16170   78.0                    NaN                  100.0
# 1            1  15871  145.0                    NaN                  100.0
# 2            2  16811  150.0                    NaN                  100.0
# 3            3  15831  105.0                    NaN                   77.0
# 4            4    876   77.0                    NaN                  100.0
# 5            5  13480  559.0                    NaN                  100.0
# 6            6  18786   41.0                    NaN                  100.0
# 7            7  15268   20.0                    NaN                  100.0
# 8            8    343   35.0                    NaN                  100.0
# 9            9   4650   27.0                    NaN                   69.0
# 10          10  12177  234.0                    NaN                  100.0
# ...

# %%
df_walking = df_sec.loc[df_sec['target'] == 'Walking']

# %%
df_walking
# Out:
#       Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 18            18  18169   20.0                    NaN                  100.0
# 20            20   7528  159.0                    NaN                   83.0
# 26            26   6597   70.0                    NaN                  100.0
# 29            29  22001   19.0                    NaN                  100.0
# 31            31   8219  517.0                    NaN                   51.0
# ...          ...    ...    ...                    ...                    ...
# 5871        5871   8576  353.0                    NaN                  100.0
# 5879        5879  12761   19.0                    NaN                  100.0
# 5881        5881   9165   77.0                    NaN                   77.0
# 5888        5888  14125    4.0                    NaN                  100.0
# 5892        5892   8278   55.0                    NaN                  100.0
#
# ...

# %%
print(df_walking.isnull().sum()[30:])
# Out:
# android.sensor.linear_acceleration#min               18
# android.sensor.linear_acceleration#max               18
# android.sensor.linear_acceleration#std               26
# android.sensor.magnetic_field#mean                   18
# android.sensor.magnetic_field#min                    18
# android.sensor.magnetic_field#max                    18
# android.sensor.magnetic_field#std                    24
# android.sensor.magnetic_field_uncalibrated#mean     218
# android.sensor.magnetic_field_uncalibrated#min      218
# android.sensor.magnetic_field_uncalibrated#max      218
# android.sensor.magnetic_field_uncalibrated#std      221
# android.sensor.orientation#mean                      19
# android.sensor.orientation#min                       19
# android.sensor.orientation#max                       19
# android.sensor.orientation#std                       24
# android.sensor.pressure#mean                        728
# android.sensor.pressure#min                         728
# ...

# %% [markdown]
# ## There are 988 Nan values in the android.sensor.step_counter#std even only for walking
