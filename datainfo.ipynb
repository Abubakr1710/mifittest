# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sec  = pd.read_csv('dataset_5secondWindow.csv')
df_hsec = pd.read_csv('dataset_halfSecondWindow.csv')

# %%
df_sec.head(30)
# Out:
#     Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0            0  16170   78.0                    NaN                  100.0
# 1            1  15871  145.0                    NaN                  100.0
# 2            2  16811  150.0                    NaN                  100.0
# 3            3  15831  105.0                    NaN                   77.0
# 4            4    876   77.0                    NaN                  100.0
# 5            5  13480  559.0                    NaN                  100.0
# 6            6  18786   41.0                    NaN                  100.0
# 7            7  15268   20.0                    NaN                  100.0
# 8            8    343   35.0                    NaN                  100.0
# 9            9   4650   27.0                    NaN                   69.0
# 10          10  12177  234.0                    NaN                  100.0
# ...

# %%
df_sec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5893 entries, 0 to 5892
# Data columns (total 71 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       5893 non-null   int64
#  1   id                                               5893 non-null   int64
#  2   time                                             5893 non-null   float64
#  3   activityrecognition#0                            0 non-null      float64
#  4   activityrecognition#1                            5893 non-null   float64
#  5   android.sensor.accelerometer#mean                5893 non-null   float64
#  6   android.sensor.accelerometer#min                 5893 non-null   float64
#  7   android.sensor.accelerometer#max                 5893 non-null   float64
#  8   android.sensor.accelerometer#std                 5893 non-null   float64
# ...

# %%
df_sec.describe()
# Out:
#        Unnamed: 0            id         time  activityrecognition#0  \
# count   5893.0000   5893.000000  5893.000000                    0.0
# mean    2946.0000  10685.407263   117.731716                    NaN
# std     1701.3069   6921.229833   126.474151                    NaN
# min        0.0000      0.000000     3.000000                    NaN
# 25%     1473.0000   4502.000000    31.000000                    NaN
# 50%     2946.0000  10959.000000    70.000000                    NaN
# 75%     4419.0000  17049.000000   152.000000                    NaN
# max     5892.0000  22045.000000   682.000000                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# count            5893.000000                        5893.000000
# mean               87.718310                          10.007976
# std                24.562728                           0.655949
# min                 3.000000                           7.369055
# ...

# %%
df_sec.head(20)
# Out:
#     Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0            0  16170   78.0                    NaN                  100.0
# 1            1  15871  145.0                    NaN                  100.0
# 2            2  16811  150.0                    NaN                  100.0
# 3            3  15831  105.0                    NaN                   77.0
# 4            4    876   77.0                    NaN                  100.0
# 5            5  13480  559.0                    NaN                  100.0
# 6            6  18786   41.0                    NaN                  100.0
# 7            7  15268   20.0                    NaN                  100.0
# 8            8    343   35.0                    NaN                  100.0
# 9            9   4650   27.0                    NaN                   69.0
# 10          10  12177  234.0                    NaN                  100.0
# ...

# %%
print(df_sec.shape)
print(df_hsec.shape)
# Out:
# (5893, 71)
# (62585, 71)

# %%
df_hsec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62585 entries, 0 to 62584
# Data columns (total 71 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       62585 non-null  int64
#  1   id                                               62585 non-null  int64
#  2   time                                             62585 non-null  float64
#  3   activityrecognition#0                            0 non-null      float64
#  4   activityrecognition#1                            62585 non-null  float64
#  5   android.sensor.accelerometer#mean                62585 non-null  float64
#  6   android.sensor.accelerometer#min                 62585 non-null  float64
#  7   android.sensor.accelerometer#max                 62585 non-null  float64
#  8   android.sensor.accelerometer#std                 62583 non-null  float64
# ...

# %%
df_hsec.describe()
# Out:
#          Unnamed: 0             id          time  activityrecognition#0  \
# count  62585.000000   62585.000000  62585.000000                    0.0
# mean   31292.000000  111294.400256   1150.046097                    NaN
# std    18066.877636   71786.050656   1260.411319                    NaN
# min        0.000000       0.000000      3.000000                    NaN
# 25%    15646.000000   46429.000000    284.000000                    NaN
# 50%    31292.000000  113960.000000    691.000000                    NaN
# 75%    46938.000000  177436.000000   1488.000000                    NaN
# max    62584.000000  229151.000000   6835.000000                    NaN
#
#        activityrecognition#1  android.sensor.accelerometer#mean  \
# count           62585.000000                       62585.000000
# mean               88.238444                           9.988878
# std                23.995054                           1.341609
# ...

# %%
df_hsec.head(20)
# Out:
#     Unnamed: 0      id  time  activityrecognition#0  activityrecognition#1  \
# 0            0  156661   3.0                    NaN                   62.0
# 1            1  156662   4.0                    NaN                   62.0
# 2            2  156663   5.0                    NaN                   62.0
# 3            3  156664   6.0                    NaN                   62.0
# 4            4  156665   7.0                    NaN                   62.0
# 5            5  156666   8.0                    NaN                   62.0
# 6            6  156667   9.0                    NaN                   62.0
# 7            7  156668  10.0                    NaN                   62.0
# 8            8  156669  11.0                    NaN                   62.0
# 9            9  156670  12.0                    NaN                   62.0
# 10          10  156671  13.0                    NaN                   62.0
# ...

# %%
df_sec
# Out:
#       Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 0              0  16170   78.0                    NaN                  100.0
# 1              1  15871  145.0                    NaN                  100.0
# 2              2  16811  150.0                    NaN                  100.0
# 3              3  15831  105.0                    NaN                   77.0
# 4              4    876   77.0                    NaN                  100.0
# ...          ...    ...    ...                    ...                    ...
# 5888        5888  14125    4.0                    NaN                  100.0
# 5889        5889  19582   32.0                    NaN                   10.0
# 5890        5890  16178   86.0                    NaN                  100.0
# 5891        5891  10973  199.0                    NaN                  100.0
# 5892        5892   8278   55.0                    NaN                  100.0
#
# ...

# %%
plt.figure(figsize=(25, 12))
sns.heatmap(df_sec.isnull(), yticklabels=False, cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25, 12))
sns.countplot(x='user', hue='target',data=df_sec.sort_values(by=['user']))
plt.legend(loc='upper right')
plt.show()

# %%
df_sec.loc[df_sec['user'] == 'U9']
# Out:
#       Unnamed: 0     id   time  activityrecognition#0  activityrecognition#1  \
# 57            57  12735  148.0                    NaN                    8.0
# 126          126  12705  118.0                    NaN                    8.0
# 200          200  12894   53.0                    NaN                  100.0
# 212          212  12729  142.0                    NaN                    8.0
# 272          272  12745    3.0                    NaN                  100.0
# ...          ...    ...    ...                    ...                    ...
# 5672        5672  12667   80.0                    NaN                    8.0
# 5680        5680  12738  151.0                    NaN                    8.0
# 5686        5686  12695  108.0                    NaN                    8.0
# 5693        5693  12639   52.0                    NaN                    8.0
# 5879        5879  12761   19.0                    NaN                  100.0
#
# ...

# %%
for col in df_sec.columns:
    print(col)
# Out:
# Unnamed: 0
# id
# time
# activityrecognition#0
# activityrecognition#1
# android.sensor.accelerometer#mean
# android.sensor.accelerometer#min
# android.sensor.accelerometer#max
# android.sensor.accelerometer#std
# android.sensor.game_rotation_vector#mean
# android.sensor.game_rotation_vector#min
# android.sensor.game_rotation_vector#max
# android.sensor.game_rotation_vector#std
# android.sensor.gravity#mean
# android.sensor.gravity#min
# android.sensor.gravity#max
# android.sensor.gravity#std
# android.sensor.gyroscope#mean
# android.sensor.gyroscope#min
# android.sensor.gyroscope#max
# android.sensor.gyroscope#std
# android.sensor.gyroscope_uncalibrated#mean
# android.sensor.gyroscope_uncalibrated#min
# android.sensor.gyroscope_uncalibrated#max
# android.sensor.gyroscope_uncalibrated#std
# android.sensor.light#mean
# android.sensor.light#min
# android.sensor.light#max
# android.sensor.light#std
# android.sensor.linear_acceleration#mean
# android.sensor.linear_acceleration#min
# ...

# %%
print(df_sec['speed#std'].isnull().sum())
# Out:
# 4575

# %%
print(df_sec.isnull().sum()[0:30])
# Out:
# Unnamed: 0                                       0
# id                                               0
# time                                             0
# activityrecognition#0                         5893
# activityrecognition#1                            0
# android.sensor.accelerometer#mean                0
# android.sensor.accelerometer#min                 0
# android.sensor.accelerometer#max                 0
# android.sensor.accelerometer#std                 0
# android.sensor.game_rotation_vector#mean       799
# android.sensor.game_rotation_vector#min        799
# android.sensor.game_rotation_vector#max        799
# android.sensor.game_rotation_vector#std        800
# android.sensor.gravity#mean                    497
# android.sensor.gravity#min                     497
# android.sensor.gravity#max                     497
# android.sensor.gravity#std                     537
# android.sensor.gyroscope#mean                  720
# ...

# %%
print(df_sec.isnull().sum()[30:])
# Out:
# android.sensor.linear_acceleration#min              494
# android.sensor.linear_acceleration#max              494
# android.sensor.linear_acceleration#std              523
# android.sensor.magnetic_field#mean                  493
# android.sensor.magnetic_field#min                   493
# android.sensor.magnetic_field#max                   493
# android.sensor.magnetic_field#std                   510
# android.sensor.magnetic_field_uncalibrated#mean     799
# android.sensor.magnetic_field_uncalibrated#min      799
# android.sensor.magnetic_field_uncalibrated#max      799
# android.sensor.magnetic_field_uncalibrated#std      806
# android.sensor.orientation#mean                     497
# android.sensor.orientation#min                      497
# android.sensor.orientation#max                      497
# android.sensor.orientation#std                      520
# android.sensor.pressure#mean                       3975
# android.sensor.pressure#min                        3975
# ...

# %%
plt.figure(figsize=(25, 12))
sns.histplot(x=df_sec['time'], kde=True,color="b",hue=df_sec["target"])
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.histplot(x=df_sec['time'],color="b",hue=df_sec["target"])
plt.show()

# %%
df_sec.drop(['activityrecognition#0','android.sensor.light#mean','android.sensor.light#min','android.sensor.light#max','android.sensor.light#std','android.sensor.pressure#mean','android.sensor.pressure#min','android.sensor.pressure#max','android.sensor.pressure#std','android.sensor.proximity#mean','android.sensor.proximity#min','android.sensor.proximity#max','android.sensor.proximity#std','android.sensor.step_counter#mean','android.sensor.step_counter#min','android.sensor.step_counter#max','android.sensor.step_counter#std','sound#std','speed#mean','speed#min','speed#max','speed#std'], axis=1, inplace=True)

# %%
df_sec.shape
# Out:
# (5893, 49)

# %%
plt.figure(figsize=(25, 12))
sns.heatmap(df_sec.isnull(), yticklabels=False, cbar=False,cmap='viridis')
plt.show()

# %%
print(df_sec.isnull().sum()[0:])
# Out:
# Unnamed: 0                                           0
# id                                                   0
# time                                                 0
# activityrecognition#1                                0
# android.sensor.accelerometer#mean                    0
# android.sensor.accelerometer#min                     0
# android.sensor.accelerometer#max                     0
# android.sensor.accelerometer#std                     0
# android.sensor.game_rotation_vector#mean           799
# android.sensor.game_rotation_vector#min            799
# android.sensor.game_rotation_vector#max            799
# android.sensor.game_rotation_vector#std            800
# android.sensor.gravity#mean                        497
# android.sensor.gravity#min                         497
# android.sensor.gravity#max                         497
# android.sensor.gravity#std                         537
# android.sensor.gyroscope#mean                      720
# ...

# %%
df_sec.head(5)
# Out:
#    Unnamed: 0     id   time  activityrecognition#1  \
# 0           0  16170   78.0                  100.0
# 1           1  15871  145.0                  100.0
# 2           2  16811  150.0                  100.0
# 3           3  15831  105.0                   77.0
# 4           4    876   77.0                  100.0
#
#    android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                           9.811476                          9.758895
# 1                           9.939207                          7.707437
# 2                           9.827178                          9.804817
# 3                           9.673039                          7.659674
# 4                           9.993466                          8.965621
#
#    android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                          9.849411                          0.014626
# 1                         17.146631                          1.775944
# ...

# %%
df_sec.groupby(['user'])['android.sensor.accelerometer#mean'].describe()
# Out:
#        count       mean       std       min        25%        50%        75%  \
# user
# U1    2470.0  10.019784  0.630708  7.689972   9.655529   9.935261  10.155342
# U10    531.0   9.880349  0.237631  9.108926   9.794881   9.838481   9.873909
# U11    167.0   9.829491  0.117809  9.566387   9.755704   9.817332   9.888869
# U12    820.0  10.157250  0.981695  9.297797   9.802074   9.823818   9.896279
# U13     90.0   9.791253  0.265531  8.880817   9.650070   9.828021   9.978748
# U2     271.0  10.168127  0.984282  7.369055   9.465629  10.022503  10.753438
# U3     331.0   9.995616  0.853346  7.674529   9.305519   9.953486  10.503687
# U4     227.0  10.064068  0.359965  9.352884   9.840995   9.951513  10.214494
# U5      17.0  10.596119  0.912947  9.708394   9.834707  10.592901  11.132643
# U6     279.0   9.862683  0.215283  9.364087   9.719677   9.830071   9.975449
# U7     397.0   9.810301  0.105913  9.051317   9.765602   9.799318   9.850441
# ...

# %%
df_sec['android.sensor.game_rotation_vector#mean']=df_sec['android.sensor.game_rotation_vector#mean'].fillna(df_sec.groupby('user')['time'].transform('mean'))

# %%
df_sec.groupby(['user'])['android.sensor.game_rotation_vector#mean'].describe()
# Out:
#        count        mean           std         min         25%         50%  \
# user
# U1    2470.0    0.858519  1.609867e-01    0.059354    0.784036    0.920468
# U10    531.0    0.680919  2.353005e-01    0.087450    0.481327    0.723256
# U11    167.0    0.773309  1.895032e-01    0.429411    0.600131    0.803158
# U12    820.0    0.499645  3.317365e-01    0.007770    0.177599    0.471345
# U13     90.0    0.717580  1.567978e-01    0.493207    0.592687    0.667697
# U2     271.0    0.893116  1.394804e-01    0.173898    0.816013    0.965806
# U3     331.0    0.843755  1.670189e-01    0.422914    0.690942    0.921058
# U4     227.0   58.806167  1.709071e-13   58.806167   58.806167   58.806167
# U5      17.0    0.778137  1.317445e-01    0.536831    0.703926    0.788921
# U6     279.0   48.039427  2.135459e-13   48.039427   48.039427   48.039427
# U7     397.0    0.623891  2.096816e-01    0.159945    0.471081    0.662089
# ...

# %%
df_sec.columns
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.linear_acceleration#mean',
# ...

# %%
print(df_hsec.isnull().sum()[0:30])
# Out:
# Unnamed: 0                                        0
# id                                                0
# time                                              0
# activityrecognition#0                         62585
# activityrecognition#1                             0
# android.sensor.accelerometer#mean                 0
# android.sensor.accelerometer#min                  0
# android.sensor.accelerometer#max                  0
# android.sensor.accelerometer#std                  2
# android.sensor.game_rotation_vector#mean       8585
# android.sensor.game_rotation_vector#min        8585
# android.sensor.game_rotation_vector#max        8585
# android.sensor.game_rotation_vector#std       10662
# android.sensor.gravity#mean                    5534
# android.sensor.gravity#min                     5534
# android.sensor.gravity#max                     5534
# android.sensor.gravity#std                    12352
# android.sensor.gyroscope#mean                  7711
# ...

# %%
print(df_hsec.isnull().sum()[30:])
# Out:
# android.sensor.linear_acceleration#min              5574
# android.sensor.linear_acceleration#max              5574
# android.sensor.linear_acceleration#std             12009
# android.sensor.magnetic_field#mean                  5381
# android.sensor.magnetic_field#min                   5381
# android.sensor.magnetic_field#max                   5381
# android.sensor.magnetic_field#std                   8387
# android.sensor.magnetic_field_uncalibrated#mean     8762
# android.sensor.magnetic_field_uncalibrated#min      8762
# android.sensor.magnetic_field_uncalibrated#max      8762
# android.sensor.magnetic_field_uncalibrated#std     12051
# android.sensor.orientation#mean                     5416
# android.sensor.orientation#min                      5416
# android.sensor.orientation#max                      5416
# android.sensor.orientation#std                      7775
# android.sensor.pressure#mean                       42214
# ...

# %%
df_sec.columns
# Out:
# Index(['Unnamed: 0', 'id', 'time', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.linear_acceleration#mean',
# ...
